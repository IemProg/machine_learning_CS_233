# %% [markdown]
# # Exercise Session 10 - Kernel Methods
#
# ## 1 Introduction
#
# Welcome to the 10th practical session of CS233 - Introduction to Machine Learning.
#
# We will continue using scikit-learn, a Python package of machine learning methods.
#
# Use it to train SVM with different kernel functions and learn how tune their parameters.
#
# We will also capture the kernel PCA as told in the lecture.

# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from plots import plot
from sklearn import svm 
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 2 Recap: Scikit-Learn
# Scikit-Learn is a machine learning library written in python. Most of the machine learning algorithms and tools are already implemented for you to use. In this exercise, we'll use this package to train SVM. In order to install scikit-learn follow instructions at this link:https://scikit-learn.org/stable/install.html

# %% [markdown]
# Scikit-Learn has modules implemented broadly for
# - Data Transformations: https://scikit-learn.org/stable/data_transforms.html
# - Model Selection and Training: https://scikit-learn.org/stable/model_selection.html
# - Supervised Techniques: https://scikit-learn.org/stable/supervised_learning.html
# - Unsupervised Techniques: https://scikit-learn.org/stable/unsupervised_learning.html

# %% [markdown]
# All the magic happens under the hood, but gives you freedom to try out more complicated stuff.
# Different methods to be noted here are
# - `fit`: Train a model with the data
# - `predict`: Use the model to predict on test data
# - `score`: Return mean accuracy on the given test data
#
# Have a look at [this](https://scikit-learn.org/stable/tutorial/basic/tutorial.html#learning-and-predicting) for simple example.

# %% [markdown]
# ## 3 Kernel SVM

# %% [markdown]
# Beyond the linear problem we discussed before, SVM can also solve non-linear classification problem by using kernel functions. We replace $\mathbf{x}_i$ with $\phi(\mathbf{x}_i)$, and then $\mathbf{x}_i^T\mathbf{x}_j$ with $k(\mathbf{x}_i,\mathbf{x}_j)$. The **dual form** of this problem is given by:
# \begin{align}
#     \underset{\{\alpha_i\}}{\operatorname{max}} \ \
#     & \sum_{i=1}^N \alpha_i - \frac 1 2 \sum_{i=1}^N\sum_{j=1}^N \alpha_i\alpha_jy_iy_jk(\mathbf{x}_i,\mathbf{x}_j)  \\
#     \operatorname{subject \ to} & \ \ \sum_{i=1}^N \alpha_iy_i = 0 \\
#                  & \ \ 0 \leq \alpha_i \leq C, \forall i \ \
# \end{align}
# **Question**
#    * How can you write $\tilde{\mathbf{w}}$ using $\alpha_i$s and function $\phi$?
#    * How is $y(\mathbf{x})$ represented using $\alpha_i$s?
#
# **Answer**
#    * $\tilde{\mathbf{w}} = \sum_{i=1}^N \alpha_iy_i\phi(x_i) $
#    * We plugging the $\tilde{\mathbf{w}}$ as,
#      \begin{align}
#        \hat{y}(\mathbf{x}) &= \tilde{\mathbf{w}}^T\phi(\mathbf{x}) + w_0 \\
#                            &= \sum_{i=1}^N \alpha_iy_ik(\mathbf{x_i},\mathbf{x}) + w_0
#      \end{align}
#    * The sum can be computed on the support vectors ($\delta$) only,
#        \begin{align}
#        \hat{y}(\mathbf{x}) & = \sum_{i \in \delta} \alpha_iy_ik(\mathbf{x_i},\mathbf{x}) + w_0
#      \end{align}
#
# Have a look at the SVM function [here.](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html) The main parameters you should look for are:
# - Kernel Function: Linear, Polynomial and RBF
# - Penalty term: C
# - Gamma: for RBF and Polynomial kernel
# - Degree: for polynomial kernel

# %% [markdown]
# ### 3.1 Linear Classification
#
# Recap from exercise 7, let's try with simple **linear classification** using SVM, but with different kernels.

# %%
from helpers import get_simple_dataset

# Get the simple dataset
X_linear, Y_linear = get_simple_dataset()
plot(X_linear, Y_linear, None, dataOnly=True)

# %% [markdown]
# #### - Linear Kernel
# Firstly, we use linear kernel.

# %%
# Use SVM with Linear kernel where C=0.1, 
# and you can also try some other C values and see what will happen
clf = svm.SVC(kernel='linear', C=0.1)

# Call the fit method
clf.fit(X_linear, Y_linear)

# Plot the decision boundary and support vectors
plot(X_linear, Y_linear, clf)

# %% [markdown]
# The above plot shows the decision boundary and margins of the learnt model. Encircled points are the support vectors.
# WARNING: if the margins go beyound the limits of axis, they are not shown or shown close to decision plane.

# %% [markdown]
# #### - Polynominal and RBF Kernels
# We will try out Polynomial and RBF kernels. Have a look at the type of decision boundary created.

# %%
# Use SVM with Polynomial kernel where C=0.1, degree=4, 
# and you can also try some other C and degree values and see what will happen

### CODE HERE ###
clf = svm.SVC(kernel='poly', C=0.1, degree=4, gamma=1.0, coef0=1.0)

clf.fit(X_linear, Y_linear)
plot(X_linear, Y_linear, clf)

# %%
# Use SVM with RBF kernel where C=0.1, gamma=0.1 , 
# and you can also try some other C and gamma values and see what will happen

### CODE HERE ###
clf = svm.SVC(kernel='rbf', C=0.1, gamma=0.1)

clf.fit(X_linear, Y_linear)
plot(X_linear, Y_linear, clf)

# %% [markdown]
# ### 3.2 Non-Linear Classification
# Util now we have worked with linear data in the given feature space. Most of the time that's not the case. We'll use non linear data and use non linear kernels to do classification. These kernels project the data to higher dimension and which help find out the decision boundary.

# %%
from helpers import get_circle_dataset

X,Y = get_circle_dataset()
plot(X,Y,None,dataOnly=True)

# %%
# Use SVM with Polynomial Kernel of different degrees
D = 2 ** np.linspace(0, 6, num=7)
for d in D:
    ## use poly kernel with C=10., gamma=1.0, coef0=1.0 and different degrees
    ### CODE HERE ###
    clf = svm.SVC(kernel='poly', C=10., degree=d, gamma=1.0, coef0=1.0)
    
    clf.fit(X, Y)
    plot(X, Y, clf)

# %%
# Use RBF Kernel with differen gammas
G = np.logspace(-2,2,num=5)
for g in G:
    ## use rbf kernel with C=0.1 and different gammas
    ### CODE HERE ###
    clf = svm.SVC(kernel='rbf', C=0.1, gamma=g)
    
    clf.fit(X, Y)
    plot(X, Y, clf)

# %% [markdown]
# **!!!** It is important to choose the approperiate parameters in the function.

# %% [markdown]
# **Question** Look at the given dataset again, which will be the best non-linear kernel in your mind? If you choose polynominal kernel, which degree will be the best? If you choose RBF kernel, which gamma will be the best?

# %% [markdown]
# **Answer**: Let's use Grid Search and Cross Validation techniques to find out the answer. We can apply K-Fold cross validation to different sets of parameters. We make use of the mean of K obtained accuracies to figure out the best model.

# %% [markdown]
# Here is the K-Fold cross validation for RBF kernel.

# %%
# K-Fold cross validation for searching parameters of RBF kernel.
from helpers import do_cross_validation, fold_indices

# seach in log space
grid_search_c = np.logspace(-4, 10, num=15)
grid_search_gamma = np.logspace(-9, 5, num=15)

#save the accuracies for the combination of hyperparameters
grid_val = np.zeros((len(grid_search_c), len(grid_search_gamma)))

# Do 4 fold cross validation
k_fold = 4
k_fold_ind = fold_indices(X.shape[0], k_fold)

for i, c in enumerate(grid_search_c):
    for j, g in enumerate(grid_search_gamma):
        print('Evaluating for C:{} gamma:{} ...'.format(c, g))
        
        ## call SVM with c,g as params.
        ### CODE HERE ####
        clf = svm.SVC(kernel='rbf', C=c, gamma=g)
        
        acc = np.zeros(k_fold)
        ## do cross validation
        for k in range(k_fold):
            acc[k] = do_cross_validation(clf, k, k_fold_ind, X, Y)
            
        ## fill out the grid_val by computing the mean accuracy from k_fold runs.
        ### CODE HERE ####
        grid_val[i,j] = np.mean(acc)
# Out:
# Evaluating for C:0.0001 gamma:1e-09 ...
# Evaluating for C:0.0001 gamma:1e-08 ...
# Evaluating for C:0.0001 gamma:1e-07 ...
# Evaluating for C:0.0001 gamma:1e-06 ...
# Evaluating for C:0.0001 gamma:1e-05 ...
# Evaluating for C:0.0001 gamma:0.0001 ...
# Evaluating for C:0.0001 gamma:0.001 ...
# Evaluating for C:0.0001 gamma:0.01 ...
# Evaluating for C:0.0001 gamma:0.1 ...
# Evaluating for C:0.0001 gamma:1.0 ...
# Evaluating for C:0.0001 gamma:10.0 ...
# Evaluating for C:0.0001 gamma:100.0 ...
# Evaluating for C:0.0001 gamma:1000.0 ...
# Evaluating for C:0.0001 gamma:10000.0 ...
# Evaluating for C:0.0001 gamma:100000.0 ...
# Evaluating for C:0.001 gamma:1e-09 ...
# Evaluating for C:0.001 gamma:1e-08 ...
# Evaluating for C:0.001 gamma:1e-07 ...
# Evaluating for C:0.001 gamma:1e-06 ...
# Evaluating for C:0.001 gamma:1e-05 ...
# Evaluating for C:0.001 gamma:0.0001 ...
# Evaluating for C:0.001 gamma:0.001 ...
# Evaluating for C:0.001 gamma:0.01 ...
# Evaluating for C:0.001 gamma:0.1 ...
# Evaluating for C:0.001 gamma:1.0 ...
# Evaluating for C:0.001 gamma:10.0 ...
# Evaluating for C:0.001 gamma:100.0 ...
# Evaluating for C:0.001 gamma:1000.0 ...
# Evaluating for C:0.001 gamma:10000.0 ...
# Evaluating for C:0.001 gamma:100000.0 ...
# Evaluating for C:0.01 gamma:1e-09 ...
# Evaluating for C:0.01 gamma:1e-08 ...
# Evaluating for C:0.01 gamma:1e-07 ...
# Evaluating for C:0.01 gamma:1e-06 ...
# Evaluating for C:0.01 gamma:1e-05 ...
# Evaluating for C:0.01 gamma:0.0001 ...
# Evaluating for C:0.01 gamma:0.001 ...
# Evaluating for C:0.01 gamma:0.01 ...
# Evaluating for C:0.01 gamma:0.1 ...
# Evaluating for C:0.01 gamma:1.0 ...
# Evaluating for C:0.01 gamma:10.0 ...
# Evaluating for C:0.01 gamma:100.0 ...
# Evaluating for C:0.01 gamma:1000.0 ...
# Evaluating for C:0.01 gamma:10000.0 ...
# Evaluating for C:0.01 gamma:100000.0 ...
# Evaluating for C:0.1 gamma:1e-09 ...
# Evaluating for C:0.1 gamma:1e-08 ...
# Evaluating for C:0.1 gamma:1e-07 ...
# Evaluating for C:0.1 gamma:1e-06 ...
# Evaluating for C:0.1 gamma:1e-05 ...
# Evaluating for C:0.1 gamma:0.0001 ...
# Evaluating for C:0.1 gamma:0.001 ...
# Evaluating for C:0.1 gamma:0.01 ...
# Evaluating for C:0.1 gamma:0.1 ...
# Evaluating for C:0.1 gamma:1.0 ...
# Evaluating for C:0.1 gamma:10.0 ...
# Evaluating for C:0.1 gamma:100.0 ...
# Evaluating for C:0.1 gamma:1000.0 ...
# Evaluating for C:0.1 gamma:10000.0 ...
# Evaluating for C:0.1 gamma:100000.0 ...
# Evaluating for C:1.0 gamma:1e-09 ...
# Evaluating for C:1.0 gamma:1e-08 ...
# Evaluating for C:1.0 gamma:1e-07 ...
# Evaluating for C:1.0 gamma:1e-06 ...
# Evaluating for C:1.0 gamma:1e-05 ...
# Evaluating for C:1.0 gamma:0.0001 ...
# Evaluating for C:1.0 gamma:0.001 ...
# Evaluating for C:1.0 gamma:0.01 ...
# Evaluating for C:1.0 gamma:0.1 ...
# Evaluating for C:1.0 gamma:1.0 ...
# Evaluating for C:1.0 gamma:10.0 ...
# Evaluating for C:1.0 gamma:100.0 ...
# Evaluating for C:1.0 gamma:1000.0 ...
# Evaluating for C:1.0 gamma:10000.0 ...
# Evaluating for C:1.0 gamma:100000.0 ...
# Evaluating for C:10.0 gamma:1e-09 ...
# Evaluating for C:10.0 gamma:1e-08 ...
# Evaluating for C:10.0 gamma:1e-07 ...
# Evaluating for C:10.0 gamma:1e-06 ...
# Evaluating for C:10.0 gamma:1e-05 ...
# Evaluating for C:10.0 gamma:0.0001 ...
# Evaluating for C:10.0 gamma:0.001 ...
# Evaluating for C:10.0 gamma:0.01 ...
# Evaluating for C:10.0 gamma:0.1 ...
# Evaluating for C:10.0 gamma:1.0 ...
# Evaluating for C:10.0 gamma:10.0 ...
# Evaluating for C:10.0 gamma:100.0 ...
# Evaluating for C:10.0 gamma:1000.0 ...
# Evaluating for C:10.0 gamma:10000.0 ...
# Evaluating for C:10.0 gamma:100000.0 ...
# Evaluating for C:100.0 gamma:1e-09 ...
# Evaluating for C:100.0 gamma:1e-08 ...
# Evaluating for C:100.0 gamma:1e-07 ...
# Evaluating for C:100.0 gamma:1e-06 ...
# Evaluating for C:100.0 gamma:1e-05 ...
# Evaluating for C:100.0 gamma:0.0001 ...
# Evaluating for C:100.0 gamma:0.001 ...
# Evaluating for C:100.0 gamma:0.01 ...
# Evaluating for C:100.0 gamma:0.1 ...
# Evaluating for C:100.0 gamma:1.0 ...
# Evaluating for C:100.0 gamma:10.0 ...
# Evaluating for C:100.0 gamma:100.0 ...
# Evaluating for C:100.0 gamma:1000.0 ...
# Evaluating for C:100.0 gamma:10000.0 ...
# Evaluating for C:100.0 gamma:100000.0 ...
# Evaluating for C:1000.0 gamma:1e-09 ...
# Evaluating for C:1000.0 gamma:1e-08 ...
# Evaluating for C:1000.0 gamma:1e-07 ...
# Evaluating for C:1000.0 gamma:1e-06 ...
# Evaluating for C:1000.0 gamma:1e-05 ...
# Evaluating for C:1000.0 gamma:0.0001 ...
# Evaluating for C:1000.0 gamma:0.001 ...
# Evaluating for C:1000.0 gamma:0.01 ...
# Evaluating for C:1000.0 gamma:0.1 ...
# Evaluating for C:1000.0 gamma:1.0 ...
# Evaluating for C:1000.0 gamma:10.0 ...
# Evaluating for C:1000.0 gamma:100.0 ...
# Evaluating for C:1000.0 gamma:1000.0 ...
# Evaluating for C:1000.0 gamma:10000.0 ...
# Evaluating for C:1000.0 gamma:100000.0 ...
# Evaluating for C:10000.0 gamma:1e-09 ...
# Evaluating for C:10000.0 gamma:1e-08 ...
# Evaluating for C:10000.0 gamma:1e-07 ...
# Evaluating for C:10000.0 gamma:1e-06 ...
# Evaluating for C:10000.0 gamma:1e-05 ...
# Evaluating for C:10000.0 gamma:0.0001 ...
# Evaluating for C:10000.0 gamma:0.001 ...
# Evaluating for C:10000.0 gamma:0.01 ...
# Evaluating for C:10000.0 gamma:0.1 ...
# Evaluating for C:10000.0 gamma:1.0 ...
# Evaluating for C:10000.0 gamma:10.0 ...
# Evaluating for C:10000.0 gamma:100.0 ...
# Evaluating for C:10000.0 gamma:1000.0 ...
# Evaluating for C:10000.0 gamma:10000.0 ...
# Evaluating for C:10000.0 gamma:100000.0 ...
# Evaluating for C:100000.0 gamma:1e-09 ...
# Evaluating for C:100000.0 gamma:1e-08 ...
# Evaluating for C:100000.0 gamma:1e-07 ...
# Evaluating for C:100000.0 gamma:1e-06 ...
# Evaluating for C:100000.0 gamma:1e-05 ...
# Evaluating for C:100000.0 gamma:0.0001 ...
# Evaluating for C:100000.0 gamma:0.001 ...
# Evaluating for C:100000.0 gamma:0.01 ...
# Evaluating for C:100000.0 gamma:0.1 ...
# Evaluating for C:100000.0 gamma:1.0 ...
# Evaluating for C:100000.0 gamma:10.0 ...
# Evaluating for C:100000.0 gamma:100.0 ...
# Evaluating for C:100000.0 gamma:1000.0 ...
# Evaluating for C:100000.0 gamma:10000.0 ...
# Evaluating for C:100000.0 gamma:100000.0 ...
# Evaluating for C:1000000.0 gamma:1e-09 ...
# Evaluating for C:1000000.0 gamma:1e-08 ...
# Evaluating for C:1000000.0 gamma:1e-07 ...
# Evaluating for C:1000000.0 gamma:1e-06 ...
# Evaluating for C:1000000.0 gamma:1e-05 ...
# Evaluating for C:1000000.0 gamma:0.0001 ...
# Evaluating for C:1000000.0 gamma:0.001 ...
# Evaluating for C:1000000.0 gamma:0.01 ...
# Evaluating for C:1000000.0 gamma:0.1 ...
# Evaluating for C:1000000.0 gamma:1.0 ...
# Evaluating for C:1000000.0 gamma:10.0 ...
# Evaluating for C:1000000.0 gamma:100.0 ...
# Evaluating for C:1000000.0 gamma:1000.0 ...
# Evaluating for C:1000000.0 gamma:10000.0 ...
# Evaluating for C:1000000.0 gamma:100000.0 ...
# Evaluating for C:10000000.0 gamma:1e-09 ...
# Evaluating for C:10000000.0 gamma:1e-08 ...
# Evaluating for C:10000000.0 gamma:1e-07 ...
# Evaluating for C:10000000.0 gamma:1e-06 ...
# Evaluating for C:10000000.0 gamma:1e-05 ...
# Evaluating for C:10000000.0 gamma:0.0001 ...
# Evaluating for C:10000000.0 gamma:0.001 ...
# Evaluating for C:10000000.0 gamma:0.01 ...
# Evaluating for C:10000000.0 gamma:0.1 ...
# Evaluating for C:10000000.0 gamma:1.0 ...
# Evaluating for C:10000000.0 gamma:10.0 ...
# Evaluating for C:10000000.0 gamma:100.0 ...
# Evaluating for C:10000000.0 gamma:1000.0 ...
# Evaluating for C:10000000.0 gamma:10000.0 ...
# Evaluating for C:10000000.0 gamma:100000.0 ...
# Evaluating for C:100000000.0 gamma:1e-09 ...
# Evaluating for C:100000000.0 gamma:1e-08 ...
# Evaluating for C:100000000.0 gamma:1e-07 ...
# Evaluating for C:100000000.0 gamma:1e-06 ...
# Evaluating for C:100000000.0 gamma:1e-05 ...
# Evaluating for C:100000000.0 gamma:0.0001 ...
# Evaluating for C:100000000.0 gamma:0.001 ...
# Evaluating for C:100000000.0 gamma:0.01 ...
# Evaluating for C:100000000.0 gamma:0.1 ...
# Evaluating for C:100000000.0 gamma:1.0 ...
# Evaluating for C:100000000.0 gamma:10.0 ...
# Evaluating for C:100000000.0 gamma:100.0 ...
# Evaluating for C:100000000.0 gamma:1000.0 ...
# Evaluating for C:100000000.0 gamma:10000.0 ...
# Evaluating for C:100000000.0 gamma:100000.0 ...
# Evaluating for C:1000000000.0 gamma:1e-09 ...
# Evaluating for C:1000000000.0 gamma:1e-08 ...
# Evaluating for C:1000000000.0 gamma:1e-07 ...
# Evaluating for C:1000000000.0 gamma:1e-06 ...
# Evaluating for C:1000000000.0 gamma:1e-05 ...
# Evaluating for C:1000000000.0 gamma:0.0001 ...
# Evaluating for C:1000000000.0 gamma:0.001 ...
# Evaluating for C:1000000000.0 gamma:0.01 ...
# Evaluating for C:1000000000.0 gamma:0.1 ...
# Evaluating for C:1000000000.0 gamma:1.0 ...
# Evaluating for C:1000000000.0 gamma:10.0 ...
# Evaluating for C:1000000000.0 gamma:100.0 ...
# Evaluating for C:1000000000.0 gamma:1000.0 ...
# Evaluating for C:1000000000.0 gamma:10000.0 ...
# Evaluating for C:1000000000.0 gamma:100000.0 ...
# Evaluating for C:10000000000.0 gamma:1e-09 ...
# Evaluating for C:10000000000.0 gamma:1e-08 ...
# Evaluating for C:10000000000.0 gamma:1e-07 ...
# Evaluating for C:10000000000.0 gamma:1e-06 ...
# Evaluating for C:10000000000.0 gamma:1e-05 ...
# Evaluating for C:10000000000.0 gamma:0.0001 ...
# Evaluating for C:10000000000.0 gamma:0.001 ...
# Evaluating for C:10000000000.0 gamma:0.01 ...
# Evaluating for C:10000000000.0 gamma:0.1 ...
# Evaluating for C:10000000000.0 gamma:1.0 ...
# Evaluating for C:10000000000.0 gamma:10.0 ...
# Evaluating for C:10000000000.0 gamma:100.0 ...
# Evaluating for C:10000000000.0 gamma:1000.0 ...
# Evaluating for C:10000000000.0 gamma:10000.0 ...
# Evaluating for C:10000000000.0 gamma:100000.0 ...

# %%
from plots import plot_cv_result_rbf
## show all results and the best one
plot_cv_result_rbf(grid_val,grid_search_c,grid_search_gamma)
print('Best acc:{}'.format(np.max(grid_val)))
## best params
cin,gin = np.unravel_index(np.argmax(grid_val),grid_val.shape)
print('Best Params- C:{}, Gamma:{}'.format(grid_search_c[cin],grid_search_gamma[gin]))
# Out:
# Best acc:0.98
# Best Params- C:100.0, Gamma:0.1

# %% [markdown]
# Above heatmap shows accuracies for different Gamma and C values. The best params are used on test set.
# **Question** Is there a relation between C and Gamma?
# **Hint**: Think how increase in one value changes other. Look at the heatmap to get the idea.

# %% [markdown]
# **Answer**: High Gamma will lead to overfitting, hence smaller C would more misclassification to counteract. Lower Gamma is underfitting and hence high C is to stop misclassification.

# %% [markdown]
# Then we do the K-Fold cross validation for polynominal kernel.

# %%
# K-Fold cross validation for searching parameters of Polynominal kernel.
from helpers import do_cross_validation, fold_indices

grid_search_c = np.logspace(-5,5,num=11)
grid_search_degree = 2 ** np.linspace(0, 8, num=9)

#save the accuracies for the combination of hyperparameters
grid_val = np.zeros((len(grid_search_c),len(grid_search_degree)))

# Do 4 fold cross validation
k_fold = 4
k_fold_ind = fold_indices(X.shape[0],k_fold)

for i, c in enumerate(grid_search_c):
    for j, d in enumerate(grid_search_degree):
        print('Evaluating for C:{} degree:{} ...'.format(c, d))
        
        ## call SVM with c,d as params.
        ### CODE HERE ####
        clf = svm.SVC(kernel='poly', C=c, degree=d, gamma=1.0, coef0=1.0)
        
        acc = np.zeros(k_fold)
        # do cross validation
        for k in range(k_fold):
            acc[k] = do_cross_validation(clf,k,k_fold_ind,X,Y)
            
        ## fill out the grid_val by computing the mean accuracy from k_fold runs. 
        ### CODE HERE ####
        grid_val[i,j] = np.mean(acc)
# Out:
# Evaluating for C:1e-05 degree:1.0 ...
# Evaluating for C:1e-05 degree:2.0 ...
# Evaluating for C:1e-05 degree:4.0 ...
# Evaluating for C:1e-05 degree:8.0 ...
# Evaluating for C:1e-05 degree:16.0 ...
# Evaluating for C:1e-05 degree:32.0 ...
# Evaluating for C:1e-05 degree:64.0 ...
# Evaluating for C:1e-05 degree:128.0 ...
# Evaluating for C:1e-05 degree:256.0 ...
# Evaluating for C:0.0001 degree:1.0 ...
# Evaluating for C:0.0001 degree:2.0 ...
# Evaluating for C:0.0001 degree:4.0 ...
# Evaluating for C:0.0001 degree:8.0 ...
# Evaluating for C:0.0001 degree:16.0 ...
# Evaluating for C:0.0001 degree:32.0 ...
# Evaluating for C:0.0001 degree:64.0 ...
# Evaluating for C:0.0001 degree:128.0 ...
# Evaluating for C:0.0001 degree:256.0 ...
# Evaluating for C:0.001 degree:1.0 ...
# Evaluating for C:0.001 degree:2.0 ...
# Evaluating for C:0.001 degree:4.0 ...
# Evaluating for C:0.001 degree:8.0 ...
# Evaluating for C:0.001 degree:16.0 ...
# Evaluating for C:0.001 degree:32.0 ...
# Evaluating for C:0.001 degree:64.0 ...
# Evaluating for C:0.001 degree:128.0 ...
# Evaluating for C:0.001 degree:256.0 ...
# Evaluating for C:0.01 degree:1.0 ...
# Evaluating for C:0.01 degree:2.0 ...
# Evaluating for C:0.01 degree:4.0 ...
# Evaluating for C:0.01 degree:8.0 ...
# Evaluating for C:0.01 degree:16.0 ...
# Evaluating for C:0.01 degree:32.0 ...
# Evaluating for C:0.01 degree:64.0 ...
# Evaluating for C:0.01 degree:128.0 ...
# Evaluating for C:0.01 degree:256.0 ...
# Evaluating for C:0.1 degree:1.0 ...
# Evaluating for C:0.1 degree:2.0 ...
# Evaluating for C:0.1 degree:4.0 ...
# Evaluating for C:0.1 degree:8.0 ...
# Evaluating for C:0.1 degree:16.0 ...
# Evaluating for C:0.1 degree:32.0 ...
# Evaluating for C:0.1 degree:64.0 ...
# Evaluating for C:0.1 degree:128.0 ...
# Evaluating for C:0.1 degree:256.0 ...
# Evaluating for C:1.0 degree:1.0 ...
# Evaluating for C:1.0 degree:2.0 ...
# Evaluating for C:1.0 degree:4.0 ...
# Evaluating for C:1.0 degree:8.0 ...
# Evaluating for C:1.0 degree:16.0 ...
# Evaluating for C:1.0 degree:32.0 ...
# Evaluating for C:1.0 degree:64.0 ...
# Evaluating for C:1.0 degree:128.0 ...
# Evaluating for C:1.0 degree:256.0 ...
# Evaluating for C:10.0 degree:1.0 ...
# Evaluating for C:10.0 degree:2.0 ...
# Evaluating for C:10.0 degree:4.0 ...
# Evaluating for C:10.0 degree:8.0 ...
# Evaluating for C:10.0 degree:16.0 ...
# Evaluating for C:10.0 degree:32.0 ...
# Evaluating for C:10.0 degree:64.0 ...
# Evaluating for C:10.0 degree:128.0 ...
# Evaluating for C:10.0 degree:256.0 ...
# Evaluating for C:100.0 degree:1.0 ...
# Evaluating for C:100.0 degree:2.0 ...
# Evaluating for C:100.0 degree:4.0 ...
# Evaluating for C:100.0 degree:8.0 ...
# Evaluating for C:100.0 degree:16.0 ...
# Evaluating for C:100.0 degree:32.0 ...
# Evaluating for C:100.0 degree:64.0 ...
# Evaluating for C:100.0 degree:128.0 ...
# Evaluating for C:100.0 degree:256.0 ...
# Evaluating for C:1000.0 degree:1.0 ...
# Evaluating for C:1000.0 degree:2.0 ...
# Evaluating for C:1000.0 degree:4.0 ...
# Evaluating for C:1000.0 degree:8.0 ...
# Evaluating for C:1000.0 degree:16.0 ...
# Evaluating for C:1000.0 degree:32.0 ...
# Evaluating for C:1000.0 degree:64.0 ...
# Evaluating for C:1000.0 degree:128.0 ...
# Evaluating for C:1000.0 degree:256.0 ...
# Evaluating for C:10000.0 degree:1.0 ...
# Evaluating for C:10000.0 degree:2.0 ...
# Evaluating for C:10000.0 degree:4.0 ...
# Evaluating for C:10000.0 degree:8.0 ...
# Evaluating for C:10000.0 degree:16.0 ...
# Evaluating for C:10000.0 degree:32.0 ...
# Evaluating for C:10000.0 degree:64.0 ...
# Evaluating for C:10000.0 degree:128.0 ...
# Evaluating for C:10000.0 degree:256.0 ...
# Evaluating for C:100000.0 degree:1.0 ...
# Evaluating for C:100000.0 degree:2.0 ...
# Evaluating for C:100000.0 degree:4.0 ...
# Evaluating for C:100000.0 degree:8.0 ...
# Evaluating for C:100000.0 degree:16.0 ...
# Evaluating for C:100000.0 degree:32.0 ...
# Evaluating for C:100000.0 degree:64.0 ...
# Evaluating for C:100000.0 degree:128.0 ...
# Evaluating for C:100000.0 degree:256.0 ...

# %%
from plots import plot_cv_result_poly
## show all results and the best one
plot_cv_result_poly(grid_val, grid_search_c, grid_search_degree)
print('Best acc:{}'.format(np.max(grid_val)))
## best params
cin,gin = np.unravel_index(np.argmax(grid_val),grid_val.shape)
print('Best Params- C:{}, Degree:{}'.format(grid_search_c[cin],grid_search_degree[gin]))
# Out:
# Best acc:0.98
# Best Params- C:10.0, Degree:2.0

# %% [markdown]
# ## 4  Kernel PCA
# In this section, we will cover the kernel PCA, in order to extend PCA to kernel PCA, we first map the data to high-dimensional space
#
#    \begin{align}
#    \mathbf{x}_i &\rightarrow \phi(\mathbf{x}_i)
#    \end{align}
#
# Then we perform PCA on $\phi(\mathbf{x}_i)$ instead of $\mathbf{x}_i$, our goal will be to replace dot products with kernel values
#
#    \begin{align}
#    k(\mathbf{x}_i, \mathbf{x}_j) &= \phi(\mathbf{x}_i)^T \phi(\mathbf{x}_j)
#    \end{align}

# %% [markdown]
# Let's first take a look at the dataset.

# %%
from sklearn.datasets import make_circles
np.random.seed(0)
X, y = make_circles(n_samples=400, factor=.3, noise=.05)

# Plot the dataset
plt.figure()
plt.title("Original space")
reds = y == 0
blues = y == 1

plt.scatter(X[reds, 0], X[reds, 1], c="red",
            s=20, edgecolor='k')
plt.scatter(X[blues, 0], X[blues, 1], c="blue",
            s=20, edgecolor='k')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.show()

# %% [markdown]
# Firstly, let's use the normal PCA.

# %%
# these functions are exactly the same as previous exercises
from helpers import PCA

# choose the top-2 principal components
d = 2
mean, W, eg, X_hat, exvar = PCA(X, d)

# Plot the results 
plt.figure()
plt.title("Projection by PCA")
reds = y == 0
blues = y == 1

plt.scatter(X_hat[reds, 0], X_hat[reds, 1], c="red",
            s=20, edgecolor='k')
plt.scatter(X_hat[blues, 0], X_hat[blues, 1], c="blue",
            s=20, edgecolor='k')
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.show()

# %% [markdown]
# As you can see, it is still not linearly separable for PCA projection in two deminsions, now, let's try kernel PCA with RBF kernel.

# %%
# Kernel PCA function
'''
Input:
    K: NxN matrix representing kernel matrix
    d: Number of principal components to be used to reduce dimensionality
    
Output:
    W: Nxd principal components
    eg: d values representing variance corresponding to principal components
    C_hat: Nxd data projected in principal components' direction
    exvar: explained variance by principal components
'''
def KPCA(K, d):
    
    # Compute eigenvector and eigenvalues. Hint use: np.linalg.eigh
    eigvals, eigvecs = np.linalg.eigh(K)
    # Choose top d eigenvalues and corresponding eigenvectors. Sort eigenvalues( with corresponding eigenvector )
    # in decreasing order first.
    eigvals = eigvals[::-1]
    eigvecs = eigvecs[:, ::-1]

    W = eigvecs[:, 0:d]
    eg = eigvals[0:d]

    # project the data using W 
    K_hat = K@W
    
    #explained variance
    exvar = eg.sum()/eigvals.sum()

    return W, eg, K_hat, exvar

# %% [markdown]
# When we utilise Kernel PCA, we should center the data $\phi(\mathbf{x}_i)$ which is after mapping original data $\mathbf{x}_i$ to feature space by kernel function $\phi$. Let's define:
# \begin{align}
#    \tilde \phi(\mathbf{x}_i) &= \phi(\mathbf{x}_i) -  \frac{1}{N} \sum_{i=1}^N \phi(\mathbf{x}_i)
#    \end{align}
#
# Then the $(i, j)^{th}$ elements of the corresponding kernel matraix is given by
#
#    \begin{align}
#    \mathbf{\tilde K}_{i,j} &= \tilde \phi(\mathbf{x}_i)^T \tilde \phi(\mathbf{x}_j)
#    \end{align}
#
# This kernel matrix can be computed based on the original one:
#
# \begin{align}
#    \mathbf{\tilde K} &= \mathbf{K} - \mathbf{1}_N \mathbf{K} - \mathbf{K} \mathbf{1}_N + \mathbf{1}_N \mathbf{K} \mathbf{1}_N
#   \end{align}
#
# where $\mathbf{1}_N$ is an $N \times N $ matrix with every elemjent equal to $1/N$.

# %%
# these functions are exactly the same as previous exercises
from helpers import kernel_rbf, kernel_matrix

sigma = 0.3

## compute original RBF kernel matrix
### CODE HERE ###
K_RBF = kernel_matrix(X, kernel_rbf, sigma)

## define the 1_N normal matrix
### CODE HERE ###
normal_matrix = np.ones(K_RBF.shape)/(K_RBF.shape[0])

## compute the centered RBF kernel matrix 
### CODE HERE ###
K_RBF_center = K_RBF - normal_matrix@K_RBF - K_RBF@normal_matrix + normal_matrix@K_RBF@normal_matrix

# use the first and second principal component obtained by kernel PCA with RBF kernel
d = 2

## call the KPCA to do the kernel PCA w.r.t centered RBF kernel matrix 
### CODE HERE ###
W_RBF_PCA, eg_RBF_PCA, K_RBF_PCA, exvar_RBF_PCA = KPCA(K_RBF_center, d)

# Visualize the kernel PCA result
plt.figure()
plt.title("Projection by kernel PCA")
reds = y == 0
blues = y == 1

plt.scatter(K_RBF_PCA[reds, 0], K_RBF_PCA[reds, 1], c="red",
            s=20, edgecolor='k')
plt.scatter(K_RBF_PCA[blues, 0], K_RBF_PCA[blues, 1], c="blue",
            s=20, edgecolor='k')
plt.xlabel("First principal component")
plt.ylabel("Second principal component")
plt.show()

# %% [markdown]
# It is linearly separable now :)
